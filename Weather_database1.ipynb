# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 602

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2deef7c57f570681a6cb1a390621c2c1

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | chichli
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | bengkulu
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | arraial do cabo
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | beloha
# Processing Record 10 of Set 1 | ye
# City not found. Skipping...
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | juneau
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | dunedin
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | turukhansk
# Processing Record 20 of Set 1 | pevek
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | narsaq
# Processing Record 23 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 1 | olafsvik
# Processing Record 25 of Set 1 | sindor
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | himora
# City not found. Skipping...
# Processing Record 31 of Set 1 | peleduy
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | murdochville
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 1 | alofi
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 1 | megion
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | belle fourche
# Processing Record 45 of Set 1 | tahe
# Processing Record 46 of Set 1 | almaznyy
# Processing Record 47 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | mindelo
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | kaspiyskiy
# Processing Record 5 of Set 2 | urusha
# Processing Record 6 of Set 2 | placido de castro
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | luanda
# Processing Record 11 of Set 2 | raudeberg
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | bud
# Processing Record 14 of Set 2 | chokurdakh
# Processing Record 15 of Set 2 | lokosovo
# Processing Record 16 of Set 2 | sambava
# Processing Record 17 of Set 2 | sao filipe
# Processing Record 18 of Set 2 | deloraine
# Processing Record 19 of Set 2 | ternate
# Processing Record 20 of Set 2 | sayyan
# Processing Record 21 of Set 2 | hami
# Processing Record 22 of Set 2 | auki
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | hervey bay
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | vila
# Processing Record 29 of Set 2 | ocos
# Processing Record 30 of Set 2 | necochea
# Processing Record 31 of Set 2 | paamiut
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | durango
# Processing Record 37 of Set 2 | north bend
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | punta arenas
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | monte patria
# Processing Record 43 of Set 2 | chazuta
# Processing Record 44 of Set 2 | meadow lake
# Processing Record 45 of Set 2 | we
# City not found. Skipping...
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | yenangyaung
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | verkhnevilyuysk
# Processing Record 50 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | pouembout
# Processing Record 2 of Set 3 | kupang
# Processing Record 3 of Set 3 | cayenne
# Processing Record 4 of Set 3 | rumoi
# Processing Record 5 of Set 3 | port elizabeth
# Processing Record 6 of Set 3 | piacabucu
# Processing Record 7 of Set 3 | acapulco
# Processing Record 8 of Set 3 | simbahan
# Processing Record 9 of Set 3 | whyalla
# Processing Record 10 of Set 3 | ajdabiya
# Processing Record 11 of Set 3 | tamiahua
# Processing Record 12 of Set 3 | kaitangata
# Processing Record 13 of Set 3 | christchurch
# Processing Record 14 of Set 3 | klaksvik
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | albany
# Processing Record 17 of Set 3 | eresos
# Processing Record 18 of Set 3 | altay
# Processing Record 19 of Set 3 | viransehir
# Processing Record 20 of Set 3 | bentiu
# Processing Record 21 of Set 3 | sorland
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | nishihara
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | khorixas
# Processing Record 26 of Set 3 | meridian
# Processing Record 27 of Set 3 | vaini
# Processing Record 28 of Set 3 | pennsville
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | sovetskiy
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | naryan-mar
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | guaruja
# Processing Record 37 of Set 3 | bardiyah
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | saint-marc
# Processing Record 40 of Set 3 | muros
# Processing Record 41 of Set 3 | aksarka
# Processing Record 42 of Set 3 | foldes
# Processing Record 43 of Set 3 | poum
# Processing Record 44 of Set 3 | port said
# Processing Record 45 of Set 3 | igarka
# Processing Record 46 of Set 3 | grindavik
# Processing Record 47 of Set 3 | asau
# Processing Record 48 of Set 3 | dinguiraye
# Processing Record 49 of Set 3 | del rio
# Processing Record 50 of Set 3 | hendersonville
# Processing Record 1 of Set 4 | newport
# Processing Record 2 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 4 | lorengau
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | besikduzu
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | kovdor
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 4 | cherskiy
# Processing Record 12 of Set 4 | flinders
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | ulladulla
# Processing Record 15 of Set 4 | bakchar
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | zunyi
# Processing Record 18 of Set 4 | sunland park
# Processing Record 19 of Set 4 | harper
# Processing Record 20 of Set 4 | okha
# Processing Record 21 of Set 4 | vestmannaeyjar
# Processing Record 22 of Set 4 | mana
# Processing Record 23 of Set 4 | chumikan
# Processing Record 24 of Set 4 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 4 | ancud
# Processing Record 26 of Set 4 | hailey
# Processing Record 27 of Set 4 | kijang
# Processing Record 28 of Set 4 | najran
# Processing Record 29 of Set 4 | bilibino
# Processing Record 30 of Set 4 | te anau
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | palmas
# Processing Record 34 of Set 4 | nargana
# Processing Record 35 of Set 4 | ulverstone
# Processing Record 36 of Set 4 | san patricio
# Processing Record 37 of Set 4 | sioux lookout
# Processing Record 38 of Set 4 | dubbo
# Processing Record 39 of Set 4 | gat
# Processing Record 40 of Set 4 | merauke
# Processing Record 41 of Set 4 | cidreira
# Processing Record 42 of Set 4 | okitipupa
# Processing Record 43 of Set 4 | binzhou
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | vila velha
# Processing Record 46 of Set 4 | goderich
# Processing Record 47 of Set 4 | harrismith
# Processing Record 48 of Set 4 | mount gambier
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | bolshaya glushitsa
# Processing Record 1 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | pangai
# Processing Record 4 of Set 5 | sabang
# Processing Record 5 of Set 5 | volodarka
# Processing Record 6 of Set 5 | governador valadares
# Processing Record 7 of Set 5 | yellowknife
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | ponta delgada
# Processing Record 12 of Set 5 | axim
# Processing Record 13 of Set 5 | lasa
# Processing Record 14 of Set 5 | dombarovskiy
# Processing Record 15 of Set 5 | nemuro
# Processing Record 16 of Set 5 | brae
# Processing Record 17 of Set 5 | bokoro
# Processing Record 18 of Set 5 | bandarbeyla
# Processing Record 19 of Set 5 | saint-augustin
# Processing Record 20 of Set 5 | broome
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | healdsburg
# Processing Record 23 of Set 5 | sompeta
# Processing Record 24 of Set 5 | nioro
# Processing Record 25 of Set 5 | lompoc
# Processing Record 26 of Set 5 | barahona
# Processing Record 27 of Set 5 | wanning
# Processing Record 28 of Set 5 | nashville
# Processing Record 29 of Set 5 | shimoda
# Processing Record 30 of Set 5 | sembakung
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | grand-lahou
# Processing Record 34 of Set 5 | maningrida
# Processing Record 35 of Set 5 | faanui
# Processing Record 36 of Set 5 | yate
# Processing Record 37 of Set 5 | galesong
# Processing Record 38 of Set 5 | san cristobal
# Processing Record 39 of Set 5 | novikovo
# Processing Record 40 of Set 5 | souillac
# Processing Record 41 of Set 5 | nanortalik
# Processing Record 42 of Set 5 | plotnikovo
# Processing Record 43 of Set 5 | ginir
# Processing Record 44 of Set 5 | valparaiso
# Processing Record 45 of Set 5 | sankt johann im pongau
# Processing Record 46 of Set 5 | zhelyabovka
# Processing Record 47 of Set 5 | kununurra
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | yerbogachen
# Processing Record 50 of Set 5 | santa rosa
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 6 | margate
# Processing Record 4 of Set 6 | plettenberg bay
# Processing Record 5 of Set 6 | evensk
# Processing Record 6 of Set 6 | jasper
# Processing Record 7 of Set 6 | garden city
# Processing Record 8 of Set 6 | komsomolskiy
# Processing Record 9 of Set 6 | conde
# Processing Record 10 of Set 6 | marakkanam
# Processing Record 11 of Set 6 | northam
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | port hedland
# Processing Record 14 of Set 6 | barrow
# Processing Record 15 of Set 6 | ambilobe
# Processing Record 16 of Set 6 | rosita
# Processing Record 17 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 18 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 19 of Set 6 | marsa matruh
# Processing Record 20 of Set 6 | enid
# Processing Record 21 of Set 6 | wakema
# Processing Record 22 of Set 6 | tautira
# Processing Record 23 of Set 6 | aasiaat
# Processing Record 24 of Set 6 | praya
# Processing Record 25 of Set 6 | dauriya
# Processing Record 26 of Set 6 | krasnyy kut
# Processing Record 27 of Set 6 | zomin
# Processing Record 28 of Set 6 | dingle
# Processing Record 29 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 6 | freeport
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | griffith
# Processing Record 33 of Set 6 | tres arroyos
# Processing Record 34 of Set 6 | kahului
# Processing Record 35 of Set 6 | cobija
# Processing Record 36 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 6 | kangaatsiaq
# Processing Record 38 of Set 6 | sungaipenuh
# Processing Record 39 of Set 6 | teguise
# Processing Record 40 of Set 6 | poya
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | marawi
# Processing Record 43 of Set 6 | srednekolymsk
# Processing Record 44 of Set 6 | palmer
# Processing Record 45 of Set 6 | mahebourg
# Processing Record 46 of Set 6 | puri
# Processing Record 47 of Set 6 | berdyuzhye
# City not found. Skipping...
# Processing Record 48 of Set 6 | methoni
# Processing Record 49 of Set 6 | kaeo
# Processing Record 50 of Set 6 | saint-georges
# Processing Record 1 of Set 7 | chifeng
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | coolum beach
# Processing Record 4 of Set 7 | bulolo
# Processing Record 5 of Set 7 | honiara
# Processing Record 6 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 7 | zhigansk
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | qabis
# City not found. Skipping...
# Processing Record 10 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 7 | imbituba
# Processing Record 12 of Set 7 | cape town
# Processing Record 13 of Set 7 | shuyskoye
# Processing Record 14 of Set 7 | egvekinot
# Processing Record 15 of Set 7 | cururupu
# Processing Record 16 of Set 7 | tasiilaq
# Processing Record 17 of Set 7 | muisne
# Processing Record 18 of Set 7 | cabedelo
# Processing Record 19 of Set 7 | togur
# Processing Record 20 of Set 7 | north platte
# Processing Record 21 of Set 7 | tayoltita
# Processing Record 22 of Set 7 | viedma
# Processing Record 23 of Set 7 | velikooktyabrskiy
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | ust-ilimsk
# Processing Record 26 of Set 7 | san lorenzo
# Processing Record 27 of Set 7 | saint george
# Processing Record 28 of Set 7 | finschhafen
# Processing Record 29 of Set 7 | ketchikan
# Processing Record 30 of Set 7 | tura
# Processing Record 31 of Set 7 | tokur
# Processing Record 32 of Set 7 | chingola
# Processing Record 33 of Set 7 | batsfjord
# Processing Record 34 of Set 7 | bonnyville
# Processing Record 35 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 36 of Set 7 | road town
# Processing Record 37 of Set 7 | uyskoye
# Processing Record 38 of Set 7 | talnakh
# Processing Record 39 of Set 7 | husavik
# Processing Record 40 of Set 7 | port alfred
# Processing Record 41 of Set 7 | santiago
# Processing Record 42 of Set 7 | boa vista
# Processing Record 43 of Set 7 | geraldton
# Processing Record 44 of Set 7 | leningradskiy
# Processing Record 45 of Set 7 | lagoa
# Processing Record 46 of Set 7 | durusu
# Processing Record 47 of Set 7 | inta
# Processing Record 48 of Set 7 | trelew
# Processing Record 49 of Set 7 | dubti
# Processing Record 50 of Set 7 | cairns
# Processing Record 1 of Set 8 | zhaotong
# Processing Record 2 of Set 8 | nizhnyaya tavda
# Processing Record 3 of Set 8 | bonavista
# Processing Record 4 of Set 8 | yumen
# Processing Record 5 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 6 of Set 8 | lavrentiya
# Processing Record 7 of Set 8 | anloga
# Processing Record 8 of Set 8 | teya
# Processing Record 9 of Set 8 | jumla
# Processing Record 10 of Set 8 | bontang
# Processing Record 11 of Set 8 | half moon bay
# Processing Record 12 of Set 8 | emba
# Processing Record 13 of Set 8 | daru
# Processing Record 14 of Set 8 | bac lieu
# Processing Record 15 of Set 8 | port lincoln
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | fairbanks
# Processing Record 18 of Set 8 | riyadh
# Processing Record 19 of Set 8 | wenling
# Processing Record 20 of Set 8 | shenzhen
# Processing Record 21 of Set 8 | mago
# Processing Record 22 of Set 8 | roberto payan
# City not found. Skipping...
# Processing Record 23 of Set 8 | tromso
# Processing Record 24 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 8 | tucuman
# Processing Record 26 of Set 8 | lingao
# Processing Record 27 of Set 8 | xinyu
# Processing Record 28 of Set 8 | izyum
# Processing Record 29 of Set 8 | mangrol
# Processing Record 30 of Set 8 | curup
# Processing Record 31 of Set 8 | santa marinella
# Processing Record 32 of Set 8 | ormara
# Processing Record 33 of Set 8 | inirida
# Processing Record 34 of Set 8 | airai
# Processing Record 35 of Set 8 | vostok
# Processing Record 36 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 37 of Set 8 | rocha
# Processing Record 38 of Set 8 | xochihuehuetlan
# Processing Record 39 of Set 8 | kirakira
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | nyrob
# Processing Record 42 of Set 8 | chapleau
# Processing Record 43 of Set 8 | anchorage
# Processing Record 44 of Set 8 | mamallapuram
# Processing Record 45 of Set 8 | seymchan
# Processing Record 46 of Set 8 | soverato
# Processing Record 47 of Set 8 | anadyr
# Processing Record 48 of Set 8 | banepa
# Processing Record 49 of Set 8 | kartaly
# Processing Record 50 of Set 8 | caravelas
# Processing Record 1 of Set 9 | gao
# Processing Record 2 of Set 9 | baykit
# Processing Record 3 of Set 9 | ponta do sol
# Processing Record 4 of Set 9 | upernavik
# Processing Record 5 of Set 9 | hamilton
# Processing Record 6 of Set 9 | rio de janeiro
# Processing Record 7 of Set 9 | iskateley
# Processing Record 8 of Set 9 | chuy
# Processing Record 9 of Set 9 | baghdad
# Processing Record 10 of Set 9 | gornyy
# Processing Record 11 of Set 9 | rumphi
# Processing Record 12 of Set 9 | yaan
# Processing Record 13 of Set 9 | oudtshoorn
# Processing Record 14 of Set 9 | jerome
# Processing Record 15 of Set 9 | aquidauana
# Processing Record 16 of Set 9 | nhulunbuy
# Processing Record 17 of Set 9 | tomatlan
# Processing Record 18 of Set 9 | weymouth
# Processing Record 19 of Set 9 | kudahuvadhoo
# Processing Record 20 of Set 9 | bonfim
# Processing Record 21 of Set 9 | byron bay
# Processing Record 22 of Set 9 | los llanos de aridane
# Processing Record 23 of Set 9 | shirokiy
# Processing Record 24 of Set 9 | quatre cocos
# Processing Record 25 of Set 9 | gobabis
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | severodvinsk
# Processing Record 28 of Set 9 | princeton
# Processing Record 29 of Set 9 | havre-saint-pierre
# Processing Record 30 of Set 9 | bintulu
# Processing Record 31 of Set 9 | juybar
# Processing Record 32 of Set 9 | funadhoo
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | herat
# Processing Record 35 of Set 9 | palu
# Processing Record 36 of Set 9 | oxbow
# Processing Record 37 of Set 9 | zhezkazgan
# Processing Record 38 of Set 9 | awbari
# Processing Record 39 of Set 9 | la palma
# Processing Record 40 of Set 9 | bathsheba
# Processing Record 41 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 9 | nyaunglebin
# Processing Record 43 of Set 9 | portland
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | nuuk
# Processing Record 46 of Set 9 | jilikul
# Processing Record 47 of Set 9 | puerto del rosario
# Processing Record 48 of Set 9 | atambua
# Processing Record 49 of Set 9 | labuhan
# Processing Record 50 of Set 9 | kudymkar
# Processing Record 1 of Set 10 | belaya gora
# Processing Record 2 of Set 10 | tukrah
# Processing Record 3 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 4 of Set 10 | sola
# Processing Record 5 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 10 | borba
# Processing Record 7 of Set 10 | bondo
# Processing Record 8 of Set 10 | kibala
# Processing Record 9 of Set 10 | belyy yar
# Processing Record 10 of Set 10 | kasempa
# Processing Record 11 of Set 10 | kitami
# Processing Record 12 of Set 10 | sayhat
# Processing Record 13 of Set 10 | port hueneme
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | vero beach
# Processing Record 16 of Set 10 | carutapera
# Processing Record 17 of Set 10 | grand gaube
# Processing Record 18 of Set 10 | makushino
# Processing Record 19 of Set 10 | kieta
# Processing Record 20 of Set 10 | da nang
# Processing Record 21 of Set 10 | albox
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | tokmak
# Processing Record 24 of Set 10 | puerto palomas
# Processing Record 25 of Set 10 | alice town
# Processing Record 26 of Set 10 | puerto suarez
# Processing Record 27 of Set 10 | kyabe
# Processing Record 28 of Set 10 | malinovoye ozero
# Processing Record 29 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | chabahar
# Processing Record 32 of Set 10 | carnarvon
# Processing Record 33 of Set 10 | gravdal
# Processing Record 34 of Set 10 | takaungu
# Processing Record 35 of Set 10 | swan hill
# Processing Record 36 of Set 10 | havoysund
# Processing Record 37 of Set 10 | gornopravdinsk
# Processing Record 38 of Set 10 | ayios kirikos
# City not found. Skipping...
# Processing Record 39 of Set 10 | melton mowbray
# Processing Record 40 of Set 10 | roald
# Processing Record 41 of Set 10 | oussouye
# Processing Record 42 of Set 10 | samandag
# Processing Record 43 of Set 10 | salar
# Processing Record 44 of Set 10 | aklavik
# Processing Record 45 of Set 10 | port hardy
# Processing Record 46 of Set 10 | samarai
# Processing Record 47 of Set 10 | el alto
# Processing Record 48 of Set 10 | burnie
# Processing Record 49 of Set 10 | ust-maya
# Processing Record 50 of Set 10 | san carlos
# Processing Record 1 of Set 11 | vanimo
# Processing Record 2 of Set 11 | mitsamiouli
# Processing Record 3 of Set 11 | gizo
# Processing Record 4 of Set 11 | dicabisagan
# Processing Record 5 of Set 11 | allapalli
# Processing Record 6 of Set 11 | huarmey
# Processing Record 7 of Set 11 | wucheng
# Processing Record 8 of Set 11 | tsiroanomandidy
# Processing Record 9 of Set 11 | mucurapo
# Processing Record 10 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 11 | bhachau
# Processing Record 12 of Set 11 | pilot butte
# Processing Record 13 of Set 11 | lanester
# Processing Record 14 of Set 11 | iwanai
# Processing Record 15 of Set 11 | kyshtovka
# Processing Record 16 of Set 11 | sechura
# Processing Record 17 of Set 11 | amudat
# Processing Record 18 of Set 11 | adrar
# Processing Record 19 of Set 11 | san quintin
# Processing Record 20 of Set 11 | bilma
# Processing Record 21 of Set 11 | malpe
# Processing Record 22 of Set 11 | kokopo
# Processing Record 23 of Set 11 | staryy krym
# Processing Record 24 of Set 11 | burns lake
# Processing Record 25 of Set 11 | la tuque
# Processing Record 26 of Set 11 | yarada
# Processing Record 27 of Set 11 | durban
# Processing Record 28 of Set 11 | bibiani
# Processing Record 29 of Set 11 | uray
# Processing Record 30 of Set 11 | kiama
# Processing Record 31 of Set 11 | bogorodskoye
# Processing Record 32 of Set 11 | bafq
# Processing Record 33 of Set 11 | boden
# Processing Record 34 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 11 | novita
# Processing Record 36 of Set 11 | mantua
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | moose factory
# Processing Record 39 of Set 11 | dasoguz
# Processing Record 40 of Set 11 | the valley
# Processing Record 41 of Set 11 | inza
# Processing Record 42 of Set 11 | rio gallegos
# Processing Record 43 of Set 11 | pilar
# Processing Record 44 of Set 11 | capao da canoa
# Processing Record 45 of Set 11 | guangyuan
# Processing Record 46 of Set 11 | nelson bay
# Processing Record 47 of Set 11 | lodja
# Processing Record 48 of Set 11 | haputale
# Processing Record 49 of Set 11 | yuzawa
# Processing Record 50 of Set 11 | gamba
# Processing Record 1 of Set 12 | kutum
# Processing Record 2 of Set 12 | innisfail
# Processing Record 3 of Set 12 | kabinda
# Processing Record 4 of Set 12 | hammerfest
# Processing Record 5 of Set 12 | kalabo
# Processing Record 6 of Set 12 | luangwa
# Processing Record 7 of Set 12 | mlimba
# Processing Record 8 of Set 12 | richards bay
# Processing Record 9 of Set 12 | coihaique
# Processing Record 10 of Set 12 | atar
# Processing Record 11 of Set 12 | znamenskoye
# Processing Record 12 of Set 12 | port macquarie
# Processing Record 13 of Set 12 | marang
# Processing Record 14 of Set 12 | sao paulo de olivenca
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | pidhorodne
# Processing Record 17 of Set 12 | constitucion
# Processing Record 18 of Set 12 | bastia
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | iracoubo
# Processing Record 21 of Set 12 | kenosha
# Processing Record 22 of Set 12 | emerald
# Processing Record 23 of Set 12 | imeni poliny osipenko
# Processing Record 24 of Set 12 | puerto escondido
# Processing Record 25 of Set 12 | honningsvag
# Processing Record 26 of Set 12 | huangmei
# Processing Record 27 of Set 12 | siva
# Processing Record 28 of Set 12 | lewistown
# Processing Record 29 of Set 12 | sur
# Processing Record 30 of Set 12 | kannur
# Processing Record 31 of Set 12 | warren
# Processing Record 32 of Set 12 | la ronge
# Processing Record 33 of Set 12 | ahipara
# Processing Record 34 of Set 12 | hobbs
# Processing Record 35 of Set 12 | bafoulabe
# Processing Record 36 of Set 12 | mezhdurechensk
# Processing Record 37 of Set 12 | meulaboh
# Processing Record 38 of Set 12 | shache
# Processing Record 39 of Set 12 | oda
# Processing Record 40 of Set 12 | shakawe
# Processing Record 41 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 42 of Set 12 | yulara
# Processing Record 43 of Set 12 | kindu
# Processing Record 44 of Set 12 | izumo
# Processing Record 45 of Set 12 | tezu
# Processing Record 46 of Set 12 | garowe
# Processing Record 47 of Set 12 | fortuna
# Processing Record 48 of Set 12 | roma
# Processing Record 49 of Set 12 | kathu
# Processing Record 50 of Set 12 | cottonwood
# Processing Record 1 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 2 of Set 13 | topeka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hithadhoo  -0.60   73.08     83.55        74           0
# 1              Kapaa  22.08 -159.32     66.20        88          40
# 2            Chichli  22.83   78.82     70.30        43           0
# 3            Ushuaia -54.80  -68.30     48.20        76          75
# 4           Bengkulu  -3.80  102.27     76.51        87         100
# 5  Sao Joao Da Barra -21.64  -41.05     82.40        74          75
# 6    Arraial Do Cabo -22.97  -42.03     78.80        83          75
# 7        Tuktoyaktuk  69.45 -133.04      4.77        93          65
# 8             Beloha -25.17   45.05     73.26        57           0
# 9          Busselton -33.65  115.33     64.00        50          14
#
#    Wind Speed Country       Description
# 0        8.97      MV         clear sky
# 1        6.93      US  scattered clouds
# 2        4.94      IN         clear sky
# 3       29.97      AR     broken clouds
# 4        4.27      ID        light rain
# 5        2.24      BR     broken clouds
# 6       14.99      BR     broken clouds
# 7        7.76      CA     broken clouds
# 8       16.67      MG         clear sky
# 9        3.51      AU        few clouds

# %%
new_column_order = ["City", "Country","Lat","Lng","Max Temp", "Humidity","Cloudiness","Wind Speed","Description"]
city_data_df = city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
